# %% [markdown]
# <div style='text-aling:right'>
# <img src="../imagens/CanalSandeco.png">
# </div>

# %% [markdown]
# <h1 style='color:blue'>ROBOTÂNICO</h1>
# <h3 style='color:red'>CRIANDO UM BOTÂNICO VIRTUAL</h3>

# %% [markdown]
# <div style='text-aling:right'>
# <img src="robotanico200.jpg">
# </div>

# %% [markdown]
# Iris é um gênero de plantas com flor muito apreciado <br/> pelas suas diversas espécies e que ostentam flores de cores muito vivas. <br/>
# São vulgarmente designadas como lírios e é uma flor muito frequente em jardins. <br/>

# %% [markdown]
# E os tipos de flores Iris são as classes:
#
# <ul>
#     <li>**SETOSA**</li>
#     <li>**VERSICOLOR**</li>
#     <li>**VIRGINICA**</li>
# </ul>

# %% [markdown]
# <div style='text-aling:right'>
# <img src="iris_classes.png">
# </div>

# %% [markdown]
# ### Machine learning e o Iris dataset
#
# - O mais famoso dataset de machine learning
# - Leia mais sobre iris dataset em: [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/datasets/Iris)
# - É um problema de **APRENDIZADO SUPERVISIONADO**: Prever a espécie de uma flor iris usando ML

# %% [markdown]
# Para a classificação das flores utilizaremos as seguintes "Caractéristicas" das flores:
# <ul>
#     <li>Altura e Largura da sépala</li>
#     <li>Altura e Largura da pétala</li>
# </ul>

# %% [markdown]
# ![Iris](iris.png)

# %% [markdown]
# # VAMOS COMEÇAR???

# %% [markdown]
# ## Carregando Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# ### Carregando o CSV em um DataFrame

# %%
df = pd.read_csv('iris.csv')

# %% [markdown]
# ### As colunas dos dados

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %% [markdown]
# ### Vendo os dados

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# ### Descrevendo os dados

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### Plotando a dispersão de dados

# %%
sb.pairplot(df, hue='target')

# %% [markdown]
# ### Selecionado as "features" para classificação em um array NUMPY

# %%
X = np.array(df.drop('target',1))
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# ### Selecionado as classes para classificação em um array NUMPY

# %%
y = np.array(df.target)
y
# Out:
# array(['SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
# ...

# %% [markdown]
# <h1 style='color:blue'>CLASSIFICANDO COM KNN</h1>
#
# O algoritmo k-vizinhos mais próximos (k-NN) é um método não-paramétrico utilizado para a classificação e regressão. Em ambos os casos, a entrada consiste em calcular a distância entre os k exemplos de treinamento mais próximos. <br/>
#
# Na classificação com o k-NN, a saída é uma associação com uma classe. Um objeto é classificado pela votação majoritária da classe dos vizinhos, sendo o objeto atribuído à classe mais comum dentre seus k vizinhos mais próximos.
#
# <br/>
# k é um inteiro positivo, tipicamente pequeno e impar. <br/>
# Se k  = 1, então o objeto é simplesmente atribuído à classe desse único vizinho mais próximo.

# %% [markdown]
# ![knn](KNN.png)

# %% [markdown]
# ### Importando KNN do scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Criando um classificador

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Treinando o classificador

# %%
knn.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %% [markdown]
# <h1 style='color:blue'>Aqui a mágica acontece</h1>
# ## Predizendo o tipo de uma flor IRIS

# %% [markdown]
# <div style='text-aling:right'>
# <img src="robotanico50.jpg">
# </div>

# %%
knn.predict([[6.5,6.5,4.7,1.3]])
# Out:
# array(['VERSICOLOR'], dtype=object)

# %%
knn.predict([[4.2,3.1,2.1,0.9]])
# Out:
# array(['SETOSA'], dtype=object)

# %% [markdown]
# ## SALVANDO O MODELO

# %%
from sklearn.externals import joblib

joblib.dump(knn, 'iris_modelo.pkl')
# Out:
# ['iris_modelo.pkl']

# %% [markdown]
# ## CARREGANDO O MODELO

# %%
from sklearn.externals import joblib

knn2 = joblib.load('iris_modelo.pkl')

# %%
knn2.classes_
# Out:
# array(['SETOSA', 'VERSICOLOR', 'VIRGINICA'], dtype=object)

# %%
knn2.predict([[4.2,3.1,2.1,5.9]])
# Out:
# array(['VIRGINICA'], dtype=object)
